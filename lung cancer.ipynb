# %%
#IMPORT LIBRARIES
import pandas as pd  #used  for working with data sets
import numpy as np #used for working with arrays
import matplotlib.pyplot as plt #used for creating 2D graphs and plots 
import seaborn as sns #used for making statistical graphics 

data = pd.read_csv('survey lung cancer.csv')
df = pd.DataFrame(data)            #storing data which has 2 indexes rows and columns

# %%
#DATA VISUALIZATION
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB

# %%
df_lung_cancer = df[df["LUNG_CANCER"]=='YES']
sns.countplot(df_lung_cancer["ANXIETY"])#counting function 
plt.title("Anxiety in people with cancer")
plt.xticks([0 , 1], ('No', 'Yes')) #xticks is used to get and the set the current tick location and labels of the x axis
plt.show()
print("YES = 142")
print("NO = 128")
# Out:
# d:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# YES = 142
# NO = 128

# %%
df.head(6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\gpsin\OneDrive\Desktop\lung cancer\lung cancer.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gpsin/OneDrive/Desktop/lung%20cancer/lung%20cancer.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df.head(6)
#
# NameError: name 'df' is not defined

# %%
df.describe #
# Out:
# <bound method NDFrame.describe of     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES
#
# [309 rows x 16 columns]>

# %%
sns.countplot(df["SMOKING"])
# Out:
# d:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SMOKING', ylabel='count'>

# %%
plt.figure(figsize=(8,4))
sns.lineplot(x=df["ANXIETY"], y=df["LUNG_CANCER"])
plt.title("ANXIETY vs LUNG_CANCER", size=20)
plt.show()

# %%
#CONVERT CATEGORIAL VALUE  TO  NUMERICAL VALUE
colum_cat = ['GENDER','LUNG_CANCER']
for i in colum_cat:
    print('-------------------------')
    print(df[i].value_counts())
    print('-------------------------')
# Out:
# -------------------------
# M    162
# F    147
# Name: GENDER, dtype: int64
# -------------------------
# -------------------------
# YES    270
# NO      39
# Name: LUNG_CANCER, dtype: int64
# -------------------------

# %%
df_clean = df.copy()
for i in colum_cat:
    print(f'Catagory of {i}')
    catlist = df_clean[i].unique()
    for j, val in enumerate(catlist):
         dftobjfinal = df_clean[i].replace({val:j},inplace=True)
         #print(dftobjfinal)
         print(j,val)
    print('--------------------------------')
# Out:
# Catagory of GENDER
# 0 M
# 1 F
# --------------------------------
# Catagory of LUNG_CANCER
# 0 YES
# 1 NO
# --------------------------------

# %%
df_clean
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         0   69        1               2        2              1
# 1         0   74        2               1        1              1
# 2         1   59        1               1        1              2
# 3         0   63        2               2        2              1
# 4         1   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       1   56        1               1        1              2
# 305       0   70        2               1        1              1
# 306       0   58        2               1        1              1
# 307       0   67        2               1        2              1
# 308       0   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#      LUNG_CANCER
# 0              0
# 1              0
# 2              1
# 3              1
# 4              1
# ..           ...
# 304            0
# 305            0
# 306            0
# 307            0
# 308            0
#
# [309 rows x 16 columns]

# %%
#DATA VISULIZATION
plt.figure(figsize=(10,6))
sns.countplot(df["SMOKING"])
plt.title("SMOKING", size=15)
plt.show()
# Out:
# d:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize = (16,10), dpi=200)
ax = plt.axes()
sns.heatmap(df.corr(), annot = True, cmap='RdBu', ax=ax)
ax.set_title('Correlation Matrix - Before Encoding & Handling Missing Data', weight='bold')
plt.show()

# %%
#DETECT OUTLINERS
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor()
y_pred = clf.fit_predict(df_clean)

# %%
x_score = clf.negative_outlier_factor_
outlier_score = pd.DataFrame()
outlier_score["score"] = x_score

#threshold (minimum value)
threshold2 = -1.5
filtre2 = outlier_score["score"] < threshold2
outlier_index = outlier_score[filtre2].index.tolist()

# %%
len(outlier_index)
# Out:
# 6

# %%
df_clean = df.copy()

# %%
g = df_clean.groupby('LUNG_CANCER')
df_balanced = g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True))
df_balanced = df_balanced.reset_index(drop=True)
x = df_balanced[['SMOKING','PEER_PRESSURE','ALCOHOL CONSUMING']]
y = df_balanced['LUNG_CANCER'].map({'YES': 1, 'NO': 0})

# %%
x
# Out:
#     SMOKING  PEER_PRESSURE  ALCOHOL CONSUMING
# 0         2              1                  1
# 1         2              1                  1
# 2         2              1                  1
# 3         1              1                  1
# 4         2              2                  1
# ..      ...            ...                ...
# 73        1              1                  1
# 74        1              2                  2
# 75        1              2                  2
# 76        2              1                  2
# 77        2              2                  1
#
# [78 rows x 3 columns]

# %%
y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 73    1
# 74    1
# 75    1
# 76    1
# 77    1
# Name: LUNG_CANCER, Length: 78, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.40, random_state = 42, shuffle=True)

# %%
#RANDOM FOREST CLASSIFIER
from sklearn.ensemble import RandomForestClassifier
r_forest = RandomForestClassifier(criterion = 'entropy', max_depth = 20, n_estimators = 10000)
r_forest.fit(x_train,y_train)
predicted = r_forest.predict(x_test)
score = r_forest.score(x_test, y_test)
rf_score_ = np.mean(score)

print('Accuracy : %.3f' % (rf_score_))
# Out:
# Accuracy : 0.781

# %%
#LOGISTIC REGRESSION
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

logmodel= LogisticRegression()
logmodel.fit(x_train,y_train)

predictions=logmodel.predict(x_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69        16
#            1       0.69      0.69      0.69        16
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.69      0.69        32
# weighted avg       0.69      0.69      0.69        32

# %%
#DEEP LEARNING
from tensorflow.keras.layers import Conv1D, Dense, Input, MaxPooling1D, Dropout, Flatten
from tensorflow.keras.models import Sequential


model_cnn = Sequential()

#model_cnn.add(Conv1D(32, kernel_size=3, padding='same', activation='relu', input_shape=(16, 1)))
#model_cnn.add(MaxPooling1D(pool_size=2))

#model_cnn.add(Conv1D(64, kernel_size=3, padding='same', activation='relu'))
#model_cnn.add(MaxPooling1D(pool_size=2))

#model_cnn.add(Conv1D(32, kernel_size=3, padding='same', activation='relu'))
#model_cnn.add(MaxPooling1D(pool_size=2))

#model_cnn.add(Dropout(0.25))
#model_cnn.add(Flatten())
#model_cnn.add(Dense(16, activation='relu'))

#model_cnn.add(Dense(5, activation='softmax'))

model_cnn.add(Dense(3, activation='relu'))
model_cnn.add(Dense(10, activation='relu'))
model_cnn.add(Dense(1, activation='sigmoid'))

model_cnn.compile(loss='binary_crossentropy', optimizer='adam', metrics='accuracy')

#model_cnn.build(input_shape=[3])

# %%
import tensorflow as tf
from tensorflow import keras
#es=tf.keras.callbacks.EarlyStopping(
#    min_delta=0.001,
#    patience=10,
#    restore_best_weights=True
#)
h_cnn = model_cnn.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20)
model_cnn.summary()
# Out:
# Epoch 1/20
# 2/2 [==============================] - 1s 386ms/step - loss: 0.6947 - accuracy: 0.4130 - val_loss: 0.6744 - val_accuracy: 0.5000
# Epoch 2/20
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6944 - accuracy: 0.4565 - val_loss: 0.6747 - val_accuracy: 0.6250
# Epoch 3/20
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6943 - accuracy: 0.5217 - val_loss: 0.6749 - val_accuracy: 0.6250
# Epoch 4/20
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6941 - accuracy: 0.5217 - val_loss: 0.6751 - val_accuracy: 0.6250
# Epoch 5/20
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6941 - accuracy: 0.5217 - val_loss: 0.6751 - val_accuracy: 0.6250
# Epoch 6/20
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6941 - accuracy: 0.5217 - val_loss: 0.6753 - val_accuracy: 0.6250
# Epoch 7/20
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6939 - accuracy: 0.5217 - val_loss: 0.6754 - val_accuracy: 0.6250
# Epoch 8/20
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6938 - accuracy: 0.5217 - val_loss: 0.6755 - val_accuracy: 0.6250
# Epoch 9/20
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6937 - accuracy: 0.5217 - val_loss: 0.6757 - val_accuracy: 0.6250
# Epoch 10/20
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6936 - accuracy: 0.5217 - val_loss: 0.6758 - val_accuracy: 0.6250
# Epoch 11/20
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6936 - accuracy: 0.5217 - val_loss: 0.6760 - val_accuracy: 0.6250
# Epoch 12/20
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6934 - accuracy: 0.5217 - val_loss: 0.6762 - val_accuracy: 0.6250
# Epoch 13/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6934 - accuracy: 0.5217 - val_loss: 0.6764 - val_accuracy: 0.6250
# Epoch 14/20
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6932 - accuracy: 0.5217 - val_loss: 0.6766 - val_accuracy: 0.6250
# Epoch 15/20
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6931 - accuracy: 0.5217 - val_loss: 0.6768 - val_accuracy: 0.6250
# Epoch 16/20
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6931 - accuracy: 0.5217 - val_loss: 0.6771 - val_accuracy: 0.6250
# Epoch 17/20
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6929 - accuracy: 0.5217 - val_loss: 0.6773 - val_accuracy: 0.6250
# Epoch 18/20
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6926 - accuracy: 0.5217 - val_loss: 0.6775 - val_accuracy: 0.6250
# Epoch 19/20
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6924 - accuracy: 0.5217 - val_loss: 0.6777 - val_accuracy: 0.6250
# Epoch 20/20
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6922 - accuracy: 0.5217 - val_loss: 0.6779 - val_accuracy: 0.6250
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 3)                 12
#
#  dense_7 (Dense)             (None, 10)                40
#
#  dense_8 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 63
# Trainable params: 63
# Non-trainable params: 0
# _________________________________________________________________

# %%
acc = h_cnn.history['accuracy']
val_acc = h_cnn.history['val_accuracy']

loss = h_cnn.history['loss']
val_loss = h_cnn.history['val_loss']


plt.figure(figsize=(12, 12))

plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy', color='r')
plt.plot(val_acc, label='Validation Accuracy', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right', fontsize=13)
plt.ylabel('Accuracy', fontsize=16, weight='bold')
plt.title('CNN - Training & Validation Acc.', fontsize=16, weight='bold')


plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss', color='r')
plt.plot(val_loss, label='Validation Loss', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='upper right', fontsize=13)
plt.ylabel('Cross Entropy', fontsize=16, weight='bold')
plt.title('CNN - Training & Validation Loss', fontsize=15, weight='bold')
plt.xlabel('Epoch', fontsize=15, weight='bold')

plt.show()

import tensorflow as tf
from tensorflow import keras
es=tf.keras.callbacks.EarlyStopping(
    min_delta=0.001,
    patience=10,
    restore_best_weights=True
)

# %%
from sklearn.metrics import classification_report

Y_pred = model_cnn.predict(x_test)
y_pred = np.round(Y_pred)

print(classification_report(y_test, y_pred))
# Out:
# 1/1 [==============================] - 0s 55ms/step
#               precision    recall  f1-score   support
#
#            0       0.58      0.94      0.71        16
#            1       0.83      0.31      0.45        16
#
#     accuracy                           0.62        32
#    macro avg       0.71      0.62      0.58        32
# weighted avg       0.71      0.62      0.58        32

# %%
import itertools
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, weight='bold', fontsize=16)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=14)
    plt.yticks(tick_marks, classes, fontsize=14)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", fontsize=12, weight='bold',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=16, weight='bold')
    plt.xlabel('Predicted label', fontsize=16, weight='bold')

cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=['1', '2'], normalize=True,
                      title='MLP - Normalized Confusion Matrix')
plt.grid(False)
plt.show()
# Out:
# Normalized confusion matrix
